# %% [markdown]
# <a href="https://colab.research.google.com/github/me1-3/Emsc2010-A3/blob/main/A3_Oxidised_Nitrogen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**1. Introduction:**

# %% [markdown]
# ###**1.1 Western Port**
#
# Western port is a large shallow embayment, which is surrounded by urban and agricultural lands, such that much of the natural landscape has been altered dramatically [3].
#
# In my study of this location, I drew data forth from the 'EPA Western Port Water Quality Data 1990 - 2025' report to analyse how the local environmental had changed over time due to man-made factors.
#
# ###**1.2 Data Set**
#
# My original data set was sourced from this site: https://discover.data.vic.gov.au/dataset/epa-western-port-water-quality-data where observations were attempted to be made monthly, over the course of 35 years, from 1990 - 2025.
#
# I cleaned the dataset to only contain the parameters that I was interested in examining: https://anu365-my.sharepoint.com/:x:/g/personal/u8216285_anu_edu_au/IQDP-tY6SH3uRbwQQZ3TutJZAX8T700pbnxJimA4K-waja4
#
# ###**1.3 Parameter**
#
# Which in this case was Oxidised Nitrogen (NOx). As according to Melbourne Water's report 'Understanding the Western Port Environment', due to catchment run-off from local agriculture, drains and groundwater, there has been a significant increase in NOx. This is most prevalent in Corinella, as it sits in the eastern arm, of which receives a disproportionately high amount of nutrient loads from the Bass River - furthermore due to eastern arm having longer residence times, NOx here accumulates more, rather than flushing quickly at other locations [3].
#
# NOx, of which is the mixture of Nitric Oxide (NO) and Nitrogen Dioxide (NO<sub>2</sub>) is a large threat towards both people and the environment as long term exposure or elevated levels damages the respiratory track, and creates both smog and acid rain [4]. In more coastal environments such Western Port, it can contribute to nutrient pollution - fueling algal blooms [3].
#
# Thereby my project seeks to examine these issues, asking the *question:*
#
# ###**1.4 Research Question & Hypothesis**
#
# *How have concentrations of oxidised nitrogen changed in Western Port Victoria both time and what are their spatial distributions?*
#
# With consideration to the extent that findings correlate to land usage and climate change?*
#
# To which I hypothesise, in accordance to my background research in the topic that:
#
# *The total percent of oxidised nitrogen at Western Port has increased due to human influence, and that Corinella will have significantly higher % of NOx.*

# %% [markdown]
# ###**1.5 Map**
#
# To give a frame of reference for the sites we are examining, I have included a map [2] of the area to visualise the spatial distribution of the site:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**1.6 MetaData**
#
# As well as provided the following Metadata to summarise the parameters chosen:
#
# <p></p>
# <table style="border-collapse: collapse; width: 474pt;" width="632">
# <tbody>
# <tr style="height: 14.25pt;">
# <td class="xl118" style="width: 84pt; height: 14.25pt;" width="112" height="19">Parameter</td>
# <td class="xl118" style="width: 114pt;" width="152">method_name</td>
# <td class="xl118" style="width: 161pt;" width="215">parameter_name</td>
# <td class="xl118" style="width: 115pt;" width="153">units</td>
# </tr>
# <tr style="height: 14.25pt;">
# <td class="xl118" style="width: 84pt; height: 14.25pt;" width="112" height="19">N_NOX</td>
# <td class="xl118" style="width: 114pt;" width="152">LAB</td>
# <td class="xl118" style="width: 161pt;" width="215">oxidised nitrogen</td>
# <td class="xl118" style="width: 115pt;" width="153">mg/L</td>
# </tr>
# </tbody>
# </table><table width="735">
# <tbody>
# <tr>
# <td width="87">site_id</td>
# <td width="220">site_name_long</td>
# <td width="138">site_name_short</td>
# <td width="108">water_body</td>
# <td width="98">latitude</td>
# <td width="84">longitude</td>
# </tr>
# <tr>
# <td>709</td>
# <td>WESTERNPORT BAY&nbsp; MCU #709</td>
# <td>Hastings</td>
# <td>Western Port</td>
# <td>-38.32913208</td>
# <td>145.2371063</td>
# </tr>
# <tr>
# <td>724</td>
# <td>WESTERNPORT BAY&nbsp; MCU #724</td>
# <td>Corinella</td>
# <td>Western Port</td>
# <td>-38.37223053</td>
# <td>145.4830017</td>
# </tr>
# <tr>
# <td>716</td>
# <td>WESTERNPORT BAY&nbsp; MCU #716</td>
# <td>Barralier Island</td>
# <td>Western Port</td>
# <td>-38.269905</td>
# <td>145.314804</td>
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>
# <div id="gtx-trans" style="position: absolute; left: -31px; top: -20px;">&nbsp;</div>

# %% [markdown]
# #**2. Code Analysis:**

# %% [markdown]
# ###**2.1 Importing Libraries, Loading and Clearing Data:**

# %% [markdown]
# I proceeded to install the necessary libraries needed for my analysis, and as well as load in the cleaned dataset that I was using, making sure to do a clean of the columns so they would run smoothly, & showing the first few rows to check.

# %%
#Install Bambi (BAyesian Model-Building Interface) for PyMC to run Bayesian statistical modeling
# !pip install bambi
# Out:
# Requirement already satisfied: bambi in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: arviz_plots<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (1.1.0)
# Requirement already satisfied: formulae<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (0.6.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from bambi) (0.21)
# Requirement already satisfied: matplotlib>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (3.10.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (2.2.2)
# Requirement already satisfied: pytensor<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (3.0.3)
# Requirement already satisfied: pymc<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (6.0.1)
# Requirement already satisfied: seaborn<0.14,>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from bambi) (0.13.2)
# Requirement already satisfied: sparse<0.18,>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from bambi) (0.17.0)
# Requirement already satisfied: arviz-base<1.2,>=1.1 in /usr/local/lib/python3.12/dist-packages (from arviz_plots<2.0.0,>=1.0.0->bambi) (1.1.0)
# Requirement already satisfied: arviz-stats<1.2,>=1.1 in /usr/local/lib/python3.12/dist-packages (from arviz-stats[xarray]<1.2,>=1.1->arviz_plots<2.0.0,>=1.0.0->bambi) (1.1.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.12/dist-packages (from formulae<0.7.0,>=0.6.0->bambi) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from formulae<0.7.0,>=0.6.0->bambi) (26.2)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from formulae<0.7.0,>=0.6.0->bambi) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.9.0->bambi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->bambi) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->bambi) (2026.2)
# Requirement already satisfied: arviz<2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pymc<7.0.0,>=6.0.0->bambi) (1.1.0)
# Requirement already satisfied: cachetools<7,>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from pymc<7.0.0,>=6.0.0->bambi) (6.2.6)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from pymc<7.0.0,>=6.0.0->bambi) (3.1.2)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from pymc<7.0.0,>=6.0.0->bambi) (13.9.4)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pymc<7.0.0,>=6.0.0->bambi) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from pymc<7.0.0,>=6.0.0->bambi) (4.15.0)
# Requirement already satisfied: setuptools>=59.0.0 in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (75.2.0)
# Requirement already satisfied: numba<=0.65.1,>=0.58 in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (0.60.0)
# Requirement already satisfied: filelock>=3.15 in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (3.29.0)
# Requirement already satisfied: etuples in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (0.3.10)
# Requirement already satisfied: logical-unification in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (0.4.7)
# Requirement already satisfied: miniKanren in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (1.0.5)
# Requirement already satisfied: cons in /usr/local/lib/python3.12/dist-packages (from pytensor<4.0.0,>=3.0.0->bambi) (0.4.7)
# Requirement already satisfied: xarray>=2024.11.0 in /usr/local/lib/python3.12/dist-packages (from arviz-base<1.2,>=1.1->arviz_plots<2.0.0,>=1.0.0->bambi) (2025.12.0)
# Requirement already satisfied: lazy_loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from arviz-base<1.2,>=1.1->arviz_plots<2.0.0,>=1.0.0->bambi) (0.5)
# Requirement already satisfied: xarray-einstats in /usr/local/lib/python3.12/dist-packages (from arviz-stats[xarray]<1.2,>=1.1->arviz_plots<2.0.0,>=1.0.0->bambi) (0.10.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<=0.65.1,>=0.58->pytensor<4.0.0,>=3.0.0->bambi) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.9.0->bambi) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->pymc<7.0.0,>=6.0.0->bambi) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->pymc<7.0.0,>=6.0.0->bambi) (2.20.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.12/dist-packages (from logical-unification->pytensor<4.0.0,>=3.0.0->bambi) (0.12.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.12/dist-packages (from logical-unification->pytensor<4.0.0,>=3.0.0->bambi) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc<7.0.0,>=6.0.0->bambi) (0.1.2)

# %%
#Import core libraries used for modelling
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
import bambi as bmb
import arviz as az
from scipy import stats
import pymc as pm
from matplotlib import colors as mcolors

# %%
# Load western port water quality data from my cleaned excel file
spreadsheet_name = "wpdata.xlsx"
worksheet_name = "Data"
df = pd.read_excel(spreadsheet_name, sheet_name=worksheet_name)

#clean the column names - strip spaces, convert to uppercase, replace spaces w/ underscores
df.columns = df.columns.str.strip().str.upper().str.replace(" ", "_")

#Show first 5 rows
df.head()
# Out:
#     SITE_NAME_SHORT    WATER_BODY       DATE  CHL_A  COLUMN2  DO_MG     SAL  \
# 0          Hastings  Western Port 1990-02-28   1.30      2.0   7.18  36.383
# 1  Barralier Island  Western Port 1990-02-28   1.45      2.0   6.97  36.643
# 2         Corinella  Western Port 1990-02-28   1.68      1.0   6.33  37.221
# 3         Corinella  Western Port 1990-04-03   1.48      0.5   7.21  37.391
# 4          Hastings  Western Port 1990-04-04   1.30      2.0   7.11  36.626
#
#     DO_SAT  TEMPERATURE   PH  ...  COLUMN1  TYPE  COLUMN3  COLUMN4  TEMP  \
# 0  100.980        21.70  NaN  ...      NaN   NaN      NaN      NaN   NaN
# 1   98.943        22.20  NaN  ...      NaN   NaN      NaN      NaN   NaN
# 2   91.129        22.80  NaN  ...      NaN   NaN      NaN      NaN   NaN
# 3   95.204        18.00  8.1  ...      NaN   NaN      NaN      NaN   NaN
# 4   95.069        18.85  8.2  ...      NaN   NaN      NaN      NaN   NaN
#
#    COLUMN9  COLUMN5  COLUMN6  COLUMN8  COLUMN7
# 0      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ###**2.2 Site selection + Time Conversion:**

# %% [markdown]
# Here I counted the number of observations of NOx made at each site, as there were only 3 total sites, I chose to keep all 3 and isolate them against each other - This way later I could analyse Hastings and Barralier Island against Corinella, to see if my assumption that Corinella would be higher than the two other Locations, As well as plot the overall trend of Western Port.
#
# In addition, I converted the date time to a decimal year such that code could read it, and did further data cleaning, removing any values that were negative, as you cannot remove more than what's available and are a source of error.

# %%
#count the num. of observations per site
df["SITE_NAME_SHORT"].value_counts()
# Out:
# SITE_NAME_SHORT
# Corinella           385
# Hastings            380
# Barralier Island    265
# Name: count, dtype: int64

# %%
#Choosing sites with the most observations
loc_types = ["Corinella", "Hastings", "Barralier Island"]
loc_1, loc_2, loc_3 = loc_types
print("Locations used:", loc_types)
# Out:
# Locations used: ['Corinella', 'Hastings', 'Barralier Island']

# %%
#Converted the date-time into a usable format - aka decimal year
df["TIME_FLOAT"] = df["DATE"].dt.year + (df["DATE"].dt.month - 1) / 12

#Defined column names such that I could parameters easily if needed
loc_col = "SITE_NAME_SHORT"
x_col = "TIME_FLOAT"
y_col = "N_NOX"

#Filtered to the three locations, so could analyse sites against each other and filtered keep only the needed columns
data = df[df[loc_col].isin([loc_1, loc_2, loc_3])].copy()
data = data[[loc_col, x_col, y_col]].dropna()

#Remove non-positive NOx values (as you cant remove more than whats available)
data = data[data[y_col] > 0].copy()

# %% [markdown]
# ###**2.3 Initial Exploratory Analysis:**

# %% [markdown]
# This scatter plot shows the 3 sites each with a substantial variability in NOx. Furthermore, Corinella shows higher and more extreme values in comparison to the other two sites. This plot is an early indicator of a small rise away from 0 in NOx over the past 3 decades, but the pattern is very noisy.

# %%
#Intial scatter plot of NOx over time - all 3 sites combined

#Assign each site a colour and symbol
colors = ["orange", "teal", "olivedrab"]
symbols =  ["^", "s", "o"]

#Scatter plot :)
plt.figure(figsize=(10, 6))
for loc, c, marker in zip([loc_1, loc_2, loc_3], colors, symbols):
    subset = data[data[loc_col] == loc]
    plt.plot(subset[x_col],
             subset[y_col],
             marker,
             alpha=0.6,
             color=c,
             label=loc)

plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel("Time (Year)")
plt.ylabel("Oxidised Nitrogen (mg/L)")
plt.legend()
plt.ylim(0, 25) #you can't get negatives
plt.xlim(1990, 2025)
plt.minorticks_on()
plt.title("Monthly Oxidised Nitrogen over Time for Three Locations")
plt.show()

# %% [markdown]
# ###**2.4 Bootstraping:**

# %% [markdown]
# Due to the relatively small amount of observations within the dataset, I decided to Bootstrap my data to create many more simulated datasets, such that I could get a good estimate for the confidence interval and establish a mean NOx for both the combined sites & one for each site.

# %% [markdown]
# - I estimated the overall mean & its uncertainty without assuming normality, to set a baseline for my later comparisons and regression modelling.
#
# - I did one for both the combined and individual.
#
# Overall, when examining the individual bootstraps you can see a clear pattern where Corinella has a much higher mean than the others, illustrating a stronger concentration at the site. This helps to inform the spatial distribution of NOx at Western Port.

# %% [markdown]
# ####**2.4.1 Bootstrap of All Sites**

# %%
#Use all NOx values from the three locations
X = data[y_col].values

#Setting a random seed & drawing random samples
np.random.seed(42)
B = np.random.choice(X, size=(len(X), 1000), replace=True)
bar = np.mean(B, axis=0)
print("Bootstrap means created:", bar.shape)
# Out:
# Bootstrap means created: (1000,)

# %%
#Plotting the bootstrap distribution of mean NOx!!!
fig, ax = plt.subplots(tight_layout=True)
n, bins, patches = ax.hist(
    bar,
    bins=30,
    edgecolor="k",
    alpha=0.75
)

#Colour by frequency
fracs = n / n.max()
norm = mcolors.Normalize(fracs.min(), fracs.max())
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)
#Establish grid
ax.set_axisbelow(True)
ax.grid(color="gray", linestyle="dashed", linewidth=0.5)

#Label
plt.xlabel("Bootstrap Mean Oxidised Nitrogen (mg/L)", style="italic")
plt.ylabel("Frequency", style="italic")
plt.title("Bootstrap Distribution of Mean Oxidised Nitrogen", fontweight="bold")

#Confidence interval
ci = np.percentile(bar, [2.5, 97.5])
print("95% confidence interval:", ci)

#Show
plt.axvline(ci[0], color="red", linestyle="dashed", linewidth=2, label="95% CI lower")
plt.axvline(ci[1], color="red", linestyle="dashed", linewidth=2, label="95% CI upper")
plt.legend()
plt.show()
# Out:
# 95% confidence interval: [ 8.23905585 11.66436458]

# %% [markdown]
# ####**2.4.2 Bootstrap Indiv.**

# %%
#Bootstrap analysis for each site separately

#Setting seed
np.random.seed(42)
#Establish locations
sites = [loc_1, loc_2, loc_3]

#plot each side-by-side via loop
fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)

for ax, loc in zip(axes, sites):
    #get values of site in loop
    site_values = data[data[loc_col] == loc][y_col].dropna().values
    #resampling of site in loop
    B = np.random.choice(site_values, size=(len(site_values), 1000), replace=True)
    boot_means = np.mean(B, axis=0)
    #95% Confidence interval
    ci_low, ci_high = np.percentile(boot_means, [2.5, 97.5])
    #Plot :)
    ax.hist(boot_means, bins=30, edgecolor="k", color="cadetblue", alpha=0.7)
    ax.axvline(ci_low, color="red", linestyle="--")
    ax.axvline(ci_high, color="red", linestyle="--")
    #each plot labels & grids
    ax.set_title(f"{loc}")
    ax.set_xlabel(f"Bootstrap Mean (mg/L), CI: {ci_low:.2f}–{ci_high:.2f}")
    ax.grid(alpha=0.3)

#y axis label
axes[0].set_ylabel("Frequency")
#show
plt.suptitle("Bootstrap Distributions of Mean Oxidised Nitrogen by Site", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###**2.5 Hypothesis Testing:**

# %% [markdown]
# After using Bootstrapping to examine where the mean might lay for the combined, as well as observed the differences in CI across individual, I want to examine if there has been an increase in mean NOx across the whole Western Port, from about the halfway point that the research was observed; 1990 - 2007, and 2007 - 2025.
#
# After defining my cut-off dates, I calculated the Bayesian models for both the early and recent periods, defining my prior mean as 9.5 mg/L from our combined bootstrap. Where I got the prior mean from our bootstrapping analysis, and used a sigma of 2 for uncertainty.

# %% [markdown]
# In the testing done below, we see that the posterior distribution is mostly centered 0, and that when we calculated a 95% HDI interval our values mostly fell within its range. Furthermore in calculating the probability that the recent mean is > early mean we got 0.99, a 99% chance of increase over time, an incredibly strong chance. However just because there is a strong possibilty of an increase, our plot does not tell how growth in NOx there was. Overall these results helped to support our hypothesis of an increase in NOx over time.

# %% [markdown]
# ####**2.5.1 Bayesian models:**

# %% [markdown]
# CUT OFF DATES -->

# %%
#cut-off dates:
#defining my early years
data_early = df[(df[x_col] <= 2007)][y_col].dropna()
data_early = data_early[data_early>0]

#defining my recent years
data_recent = df[(df[x_col] > 2007)][y_col].dropna()
data_recent = data_recent[data_recent>0]

# %% [markdown]
# EARLY -->

# %%
#Bayesian model for early period

with pm.Model() as early_model:
  #prior for the mean
  mu = pm.Normal("mu", mu = 9.5, sigma = 2)
  #prior for the standard deviation
  sigma = pm.HalfNormal ("sigma", sigma = 2)
  # likelihood
  obs = pm.Normal ("obs", mu = mu, sigma = sigma, observed = data_early)
  #sample from the posterior
  trace_early = pm.sample(20000, tune = 2000, return_inferencedata = True, progressbar = False)

#Plot the posterior dist for the mean
az.plot_dist(trace_early, var_names=["mu"])

# %% [markdown]
# RECENT -->

# %%
#Bayesian model for recent period

with pm.Model() as recent_model:
  #prior for mean
  mu = pm.Normal("mu", mu = 9.5, sigma = 2)
  #prior for standard deviation
  sigma = pm.HalfNormal ("sigma", sigma = 2)
  #likelihood
  obs = pm.Normal ("obs", mu = mu, sigma = sigma, observed = data_recent)
  #sample from the posterior
  trace_recent = pm.sample(20000, tune = 2000, return_inferencedata = True, progressbar = False)

  #Plot the posterior dist for the mean
  az.plot_dist(trace_early, var_names=["mu"])

# %% [markdown]
# ####**2.5.2 Posterior Difference:**

# %%
#extract samples from both models
mu_samples_early = trace_early.posterior["mu"].values.flatten()
mu_samples_recent = trace_recent.posterior["mu"].values.flatten()

#diff in means, recent - early
mu_diff = mu_samples_recent - mu_samples_early

# %%
#histogram
plt.hist(mu_diff, bins = 51, color="cadetblue", edgecolor="k")
#zero reference line
plt.axvline(0, color="red", linestyle="dashed")
#labels
plt.xlabel("Difference in Mean Oxidised Nitrogen [mg/L]")
plt.ylabel("Frequency")
plt.title("Posterior Distribution of Mean Difference")
#show
plt.show() #show plot

# %% [markdown]
# ####**2.5.3 Probability of Increase:**

# %%
#calc 95% HDI
az.hdi(mu_diff, prob = 0.95)
# Out:
# array([0.78986177, 5.99975515])

# %%
#Calc that prob of recent mean > early mean
np.mean(mu_diff > 0)
# Out:
# np.float64(0.99415)

# %% [markdown]
# ###**2.6 Bayesian Regression Analysis:**

# %% [markdown]
# Here I have moved on to analyse NOx's trend over time, plotting both each site on top of each other to get an estimate for the spatial distribution and combined for an overall temporal one.

# %% [markdown]
# First I scaled time, and created my polynomial terms. I then used these terms to compare them against each other to find the best model to use for my regression analysis, which was the linear model (rank 0) for oxidised nitrogen across the three locations. The linear model helps to provide a simple summary of the trend of the data. I then ran my priors for my linear model. They were extremely broad and centered around 0, which reflects weak assumptions about the NOx concentration over time. The posterior plots for my regression models, when examining the MCMC chains had good overlap and convergence.
#
# I then established the predictive ranges for each and their individual HDIs for each site before using that information and plotting a combined version onto one plot. The posterior represented the model's best estimation for where the true mean could lie, and there was a trend where the uncertainty increased as the linear model approached the limits of the x-axis, as well as dipping below the x-axis, a limitation of the model.
#
# However when we look at 2.5.5, our individual plot we see interesting trends. First of all the Corinella Site has a much higher % of NOx in comparison to the other sites. However what is fascinating is that Barralier Island actually decreases over time in comparison to Hastings which increases, crossing over each other around 2005. This *disproves* my hypothesis, indicating that there are other factors at play affecting the NOx content.

# %% [markdown]
# ####**2.6.1 Scaling time & creating polynomial terms:**

# %%
#scale time for numerical stability
data["x_scaled"] = (data[x_col] - data[x_col].mean()) / data[x_col].std()

#quadratic and cubic terms
data["x2_scaled"] = data["x_scaled"] ** 2
data["x3_scaled"] = data["x_scaled"] ** 3

# %% [markdown]
# ####**2.6.2 fit linear, quadratic, cubic models & compare**

# %%
#linear - 1st order polynomial
model_linear = bmb.Model(f"{y_col} ~ x_scaled * {loc_col}", data)
idata_linear = model_linear.fit(idata_kwargs={"log_likelihood": True}, progressbar=False)

#quadratic - 2nd order polynomial
model_quadratic = bmb.Model(f"{y_col} ~ x_scaled + x2_scaled * {loc_col}", data)
idata_quadratic = model_quadratic.fit(idata_kwargs={"log_likelihood": True}, progressbar=False)

#cubic - 3rd order polynomial
model_cubic = bmb.Model(f"{y_col} ~ x_scaled + x2_scaled + x3_scaled * {loc_col}", data)
idata_cubic = model_cubic.fit(idata_kwargs={"log_likelihood": True}, progressbar=False)

#false progress bars so that once in the Github it wasn't invalid
# Out:
# /usr/local/lib/python3.12/dist-packages/pymc/sampling/mcmc.py:1163: FutureWarning: Passing `log_likelihood` via `idata_kwargs` is deprecated and will be removed in future versions. Call `pm.compute_log_likelihood(idata)` instead.
#   return _sample_return(
# /usr/local/lib/python3.12/dist-packages/pymc/sampling/mcmc.py:1163: FutureWarning: Passing `log_likelihood` via `idata_kwargs` is deprecated and will be removed in future versions. Call `pm.compute_log_likelihood(idata)` instead.
#   return _sample_return(
# /usr/local/lib/python3.12/dist-packages/pymc/sampling/mcmc.py:1163: FutureWarning: Passing `log_likelihood` via `idata_kwargs` is deprecated and will be removed in future versions. Call `pm.compute_log_likelihood(idata)` instead.
#   return _sample_return(

# %%
#compare models using arviz, 0 is best model
cmp = az.compare(
    {"linear": idata_linear, "quadratic": idata_quadratic, "cubic": idata_cubic},
    method="BB-pseudo-BMA"
)
cmp
# Out:
# /usr/local/lib/python3.12/dist-packages/arviz_stats/loo/helper_loo.py:1146: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz_stats/loo/helper_loo.py:1146: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/arviz_stats/loo/helper_loo.py:1146: UserWarning: Estimated shape parameter of Pareto distribution is greater than 0.70 for one or more samples. You should consider using a more robust model, this is because importance sampling is less likely to work well if the marginal posterior and LOO posterior are very different. This is more likely to happen with a non-robust model and highly influential observations.
#   warnings.warn(
#            rank    elpd     p  elpd_diff  weight     se  dse  warning
# linear        0 -3600.0  43.4        0.0    0.71  160.0  0.0     True
# cubic         1 -3600.0  46.3       -3.0    0.22  160.0  3.9     True
# quadratic     2 -3600.0  44.2       -3.0    0.06  160.0  2.3     True

# %% [markdown]
# ####**2.6.3 priors and posteriors:**

# %%
#uplot priors used by bambi
model_linear.plot_priors()
plt.tight_layout()
plt.show()

# %% [markdown]
# Priors for the linear regression model. They are incredibly broad and centered around zero, reflecting weak prior assumptions about the relationship between oxidised nitrogen and time.

# %%
#plot sampled posterior distributions
az.plot_trace(idata_linear)
plt.tight_layout()
plt.show()

# %% [markdown]
# ####**2.6.4 Predictive ranges + HDIs for each Loc:**

# %%
#predict across a number of years, 1990 - 2025
x_range = np.linspace(data[x_col].min(), data[x_col].max(), 1000)
x_range_scaled = (x_range - data[x_col].mean()) / data[x_col].std()
#define scaled 2nd and 3rd order polynomial terms for range
x2_range_scaled = x_range_scaled ** 2
x3_range_scaled = x_range_scaled ** 3

# %%
#new dataframe for predictive for location 1
new_data_loc1 = pd.DataFrame({
    "x_scaled": x_range_scaled,
    "x2_scaled": x2_range_scaled,
    "x3_scaled": x3_range_scaled,
    loc_col: loc_1
})
idata_pred_loc1_params = model_linear.predict(idata_linear,
                                             data=new_data_loc1,
                                             kind="response_params",
                                             inplace=False)
idata_pred_loc1_resp = model_linear.predict(idata_linear,
                                           data=new_data_loc1,
                                           kind="response",
                                           inplace=False)
#predict distribution of regression lines each year
mu_draws_loc1 = idata_pred_loc1_params.posterior["mu"].stack(draws=("chain","draw")).values.T
pps_draws_loc1 = idata_pred_loc1_resp.posterior_predictive[y_col].stack(draws=("chain","draw")).values.T
#compute HDI and mean of posterior predictive distribution

posterior_mean_loc1 = pps_draws_loc1.mean(axis=0)
hdi_mean_loc1 = az.hdi(mu_draws_loc1, prob=0.95, axis=0)
hdi_pps_loc1 = az.hdi(pps_draws_loc1, prob=0.95, axis=0)

# %%
#predictions for location 2
new_data_loc2 = pd.DataFrame({
    "x_scaled": x_range_scaled,
    "x2_scaled": x2_range_scaled,
    "x3_scaled": x3_range_scaled,
    loc_col: loc_2
})
idata_pred_loc2_params = model_linear.predict(idata_linear,
                                             data=new_data_loc2,
                                             kind="response_params",
                                             inplace=False)
idata_pred_loc2_resp = model_linear.predict(idata_linear,
                                           data=new_data_loc2,
                                           kind="response",
                                           inplace=False)
#predict distribution of regression lines each year
mu_draws_loc2 = idata_pred_loc2_params.posterior["mu"].stack(draws=("chain","draw")).values.T
pps_draws_loc2 = idata_pred_loc2_resp.posterior_predictive[y_col].stack(draws=("chain","draw")).values.T
#compute HDI and mean of posterior predictive distribution
posterior_mean_loc2 = pps_draws_loc2.mean(axis=0)
hdi_mean_loc2 = az.hdi(mu_draws_loc2, prob=0.95, axis=0)
hdi_pps_loc2 = az.hdi(pps_draws_loc2, prob=0.95, axis=0)

# %%
# Predictions for location 3
new_data_loc3 = pd.DataFrame({
    "x_scaled": x_range_scaled,
    "x2_scaled": x2_range_scaled,
    "x3_scaled": x3_range_scaled,
    loc_col: loc_3
})
idata_pred_loc3_params = model_linear.predict(idata_linear,
                                             data=new_data_loc3,
                                             kind="response_params",
                                             inplace=False)
idata_pred_loc3_resp = model_linear.predict(idata_linear,
                                           data=new_data_loc3,
                                           kind="response",
                                           inplace=False)
#predict distribution of regression lines each year
mu_draws_loc3 = idata_pred_loc3_params.posterior["mu"].stack(draws=("chain","draw")).values.T
pps_draws_loc3 = idata_pred_loc3_resp.posterior_predictive[y_col].stack(draws=("chain","draw")).values.T
#compute HDI and mean of posterior predictive distribution
posterior_mean_loc3 = pps_draws_loc3.mean(axis=0)
hdi_mean_loc3 = az.hdi(mu_draws_loc3, prob=0.95, axis=0)
hdi_pps_loc3 = az.hdi(pps_draws_loc3, prob=0.95, axis=0)

# %% [markdown]
# ####**2.6.5 Individual comparison plot**

# %%
#Linear model - plot all 3 against each other
plt.figure(figsize=(12, 7))

for loc, c, mean, hdi_m in [
    (loc_1, colors[0], posterior_mean_loc1, hdi_mean_loc1),
    (loc_2, colors[1], posterior_mean_loc2, hdi_mean_loc2),
    (loc_3, colors[2], posterior_mean_loc3, hdi_mean_loc3),
]:
    subset = data[data[loc_col] == loc]
    plt.plot(subset[x_col], subset[y_col], "o", color=c, alpha=0.3, label=f"{loc} observed")
    plt.plot(x_range, mean, color=c, label=f"{loc} mean")
    plt.fill_between(x_range, hdi_m[:, 0], hdi_m[:, 1], alpha=0.2, color=c)
plt.ylim(0, 30)
plt.xlim(1990, 2025)
plt.xlabel("Time (Year)")
plt.ylabel("Oxidised Nitrogen (mg/L)")
plt.title("Linear Bayesian regression with 95% HDIs")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# #**3. Conclusion:**

# %% [markdown]
# ###**3.1 Findings:**
#
# Overall by using a Bootstrap analysis of my data, we discovered that the average NOx concentration for all the combined sites was around 9.5 - with individual bootstraps of each site showing a severe dichotomy in NOx concentration, where Corinella had a much higher content, compared to Hastings and Barralier Island. We then used Hypothesis testing to check if there was a trend of NOx increase over time, which (using the bootstrap as our posterior mean) found a 99% chance of an increase. This increase further reflected in Bayesian Regression analysis. However here we noticed that Barralier actually had a decreasing amount of NOx over time, which disproved my hypothesis.
#
#
# ###**3.2 Limitations & Uncertainties:**
# However these findings have a degree of uncertainty to them, despite trying to clean the data of negative values there are still uncertainty trends below the x-axis, which having a negative NOx is impossible. Furthermore the sampling of my data was attempted to be "Monthly (where possible)" [1] but was inconsistent. Furthermore the large amount of noise from the Corinella had a strong influence on both bootstrap and regression results. Furthermore for our forays into spatial distribution, the dataset only had 3 sites, which limited generalisation. My wide HDI also reflected a high amount of variability within NOx.
#
# ###**3.3 Implications:**
#
# Overall, in addressing elements of my hypothesis we can state whilst there is a gradual increasing trend in NOx it is highly dependent on location. We have already addressed how local infrastructure from nearby Corinella has polluted the surrounding water quality, and the same can be stated of the Hastings site, which also is in a built-up environment. These factors actually explain why we see a decrease in NOx at Barralier Island, as it is offshore, above scrub point on the map [2], next to the French Island National Park and thus less built up and can more easily recover. We, in addressing our research question can therefore state that urban infrastructure is indicative of a rise in NOx.

# %% [markdown]
# #**References:**

# %% [markdown]
# 1. EPA Western Port Water Quality Data 1990 - 2025 - Victorian Government Data Directory. (2025). Vic.gov.au. https://discover.data.vic.gov.au/dataset/epa-western-port-water-quality-data
#
# 2. French Island National Park. (n.d.). Western Port [Map]. Wikimedia Commons. https://en.wikipedia.org/wiki/Western_Port#/media/File:French_Island_National_Park.png
#
#
# 3. Melbourne Water. (2011). Understanding the Western Port Environment A summary of current knowledge and priorities for future research. https://www.melbournewater.com.au/sites/default/files/2018-02/Understanding_the_Western_Port_Environment_0.pdf
#
# 4. Queensland Government. (2013, August 29). Nitrogen oxides | Air pollutants. Www.qld.gov.au; Queensland Government. https://www.qld.gov.au/environment/management/monitoring/air/air-pollution/pollutants/nitrogen-oxides
